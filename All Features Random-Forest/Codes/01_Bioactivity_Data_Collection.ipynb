# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**\
# # Prostaglandin E synthase

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('CHEMBL5658')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'O14684', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0                           Prostaglandin E synthase   13.0
# 1            Prostaglandin E synthase/G/H synthase 2    9.0
# 2  Baculoviral IAP repeat-containing protein 2/Pr...    6.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL5658
# 1               False    CHEMBL3885623
# 2               False    CHEMBL4802030
#
#                                    target_components  \
# 0  [{'accession': 'O14684', 'component_descriptio...
# 1  [{'accession': 'P35354', 'component_descriptio...
# 2  [{'accession': 'Q13490', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1               PROTEIN FAMILY    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL5658'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2227  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2228  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2229                                               None   Not Determined
# 2230  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2231  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0         2594306                                                 []
# 1         2594307                                                 []
# 2         2594308                                                 []
# 3         2594309                                                 []
# 4         2594310                                                 []
# ...           ...                                                ...
# 2227     24979182  [{'comments': None, 'relation': '=', 'result_f...
# 2228     24979183  [{'comments': None, 'relation': '=', 'result_f...
# 2229     24979184  [{'comments': None, 'relation': '=', 'result_f...
# 2230     24979185  [{'comments': None, 'relation': '=', 'result_f...
# 2231     25039668  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 1      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 2      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 3      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 4      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# ...              ...                                                ...
# 2227   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2228   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2229   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2230   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2231   CHEMBL5244396  Inhibition of mPGES-1 activity in IL-1beta hum...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2227          B                    None                   None  BAO_0000190
# 2228          B                    None                   None  BAO_0000190
# 2229          B                    None                   None  BAO_0000190
# 2230          B                    None                   None  BAO_0000190
# 2231          B                    None                   None  BAO_0000190
#
#       ... target_organism          target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 1     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 3     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 4     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# ...   ...             ...                       ...           ...        ...
# 2227  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2228  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2229  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2230  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2231  ...    Homo sapiens  Prostaglandin E synthase          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   3.9
# 1     None  IC50    uM  UO_0000065        None   5.1
# 2     None  IC50    uM  UO_0000065        None   5.6
# 3     None  IC50    uM  UO_0000065        None   2.6
# 4     None  IC50    uM  UO_0000065        None   1.6
# ...    ...   ...   ...         ...         ...   ...
# 2227  None  IC50    uM  UO_0000065        None   3.1
# 2228  None  IC50    uM  UO_0000065        None  0.15
# 2229  None  IC50  None        None        None  None
# 2230  None  IC50    uM  UO_0000065        None   1.7
# 2231  None  IC50    uM  UO_0000065        None   0.2
#
# [2232 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('PGES_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2224  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2227  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2228  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2230  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2231  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0         2594306                                                 []
# 1         2594307                                                 []
# 2         2594308                                                 []
# 3         2594309                                                 []
# 4         2594310                                                 []
# ...           ...                                                ...
# 2224     24979179  [{'comments': None, 'relation': '=', 'result_f...
# 2227     24979182  [{'comments': None, 'relation': '=', 'result_f...
# 2228     24979183  [{'comments': None, 'relation': '=', 'result_f...
# 2230     24979185  [{'comments': None, 'relation': '=', 'result_f...
# 2231     25039668  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 1      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 2      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 3      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# 4      CHEMBL1014420  Inhibition of PGES1 in human A549 cell microso...
# ...              ...                                                ...
# 2224   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2227   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2228   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2230   CHEMBL5225584  Inhibition of mPGES-1 activity in IL-1beta sti...
# 2231   CHEMBL5244396  Inhibition of mPGES-1 activity in IL-1beta hum...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2224          B                    None                   None  BAO_0000190
# 2227          B                    None                   None  BAO_0000190
# 2228          B                    None                   None  BAO_0000190
# 2230          B                    None                   None  BAO_0000190
# 2231          B                    None                   None  BAO_0000190
#
#       ... target_organism          target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 1     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 3     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 4     ...    Homo sapiens  Prostaglandin E synthase          9606       None
# ...   ...             ...                       ...           ...        ...
# 2224  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2227  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2228  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2230  ...    Homo sapiens  Prostaglandin E synthase          9606       None
# 2231  ...    Homo sapiens  Prostaglandin E synthase          9606       None
#
#       toid  type units    uo_units upper_value value
# 0     None  IC50    uM  UO_0000065        None   3.9
# 1     None  IC50    uM  UO_0000065        None   5.1
# 2     None  IC50    uM  UO_0000065        None   5.6
# 3     None  IC50    uM  UO_0000065        None   2.6
# 4     None  IC50    uM  UO_0000065        None   1.6
# ...    ...   ...   ...         ...         ...   ...
# 2224  None  IC50    uM  UO_0000065        None   0.2
# 2227  None  IC50    uM  UO_0000065        None   3.1
# 2228  None  IC50    uM  UO_0000065        None  0.15
# 2230  None  IC50    uM  UO_0000065        None   1.7
# 2231  None  IC50    uM  UO_0000065        None   0.2
#
# [2134 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL518038        CCCCCCC(Sc1nc(Cl)cc(Nc2cccc(C)c2C)n1)C(=O)O
# 1          CHEMBL455936  Cc1cccc(Nc2cc(Cl)nc(SC(C(=O)O)c3cccc4ccccc34)n...
# 2          CHEMBL459722    CCCCCCC(Sc1nc(Cl)cc(Nc2ccc3ncccc3c2)n1)C(=O)OCC
# 3          CHEMBL457000  CCCCCCC(Sc1nc(Cl)cc(Nc2cc(OCC(F)(F)F)cc(OCC(F)...
# 4          CHEMBL460616  CCCCCCC(Sc1nc(Cl)cc(Nc2ccc(-c3ccccc3)cc2)n1)C(...
# ...                 ...                                                ...
# 2129      CHEMBL5284133   O=C(Nc1nnc(-c2ccc(-c3cccc(O)c3)cc2)s1)c1ccccc1Br
# 2130      CHEMBL5274544  Cc1cc(C(=O)Nc2nnc(-c3ccc(-c4ccccc4N)cc3)s2)cc(...
# 2131      CHEMBL5284121     Nc1ccccc1-c1ccc(-c2nnc(NC(=O)c3ccccc3Br)s2)cc1
# 2132      CHEMBL5285589  Nc1ccccc1-c1ccc(-c2nnc(NC(=O)c3c(Cl)ccnc3Cl)s2...
# 2133      CHEMBL2036163       CC(C)Cc1ccc(C(C)c2nc3ccccc3n2Cc2ccccc2Cl)cc1
#
#      bioactivity_class standard_value
# 0         intermediate         3900.0
# 1         intermediate         5100.0
# 2         intermediate         5600.0
# 3         intermediate         2600.0
# 4         intermediate         1600.0
# ...                ...            ...
# 2129            active          200.0
# 2130      intermediate         3100.0
# 2131            active          150.0
# 2132      intermediate         1700.0
# 2133            active          200.0
#
# [2134 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('01_PGES_bioactivity_preprocessed_data.csv', index=False)

# %% [markdown]
# ---
